# %%
import tensorflow as tf
import cv2

# %%
#model = tf.keras.models.load_model('models/cnn_mnist_2.h5')
model = tf.keras.models.load_model('models/cnnMnist_2.h5')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 128)               802944
#
#  dense_1 (Dense)             (None, 10)                1290
#
# ...
# Total params: 804,554
# Trainable params: 804,554
# Non-trainable params: 0
# _________________________________________________________________

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img2 = cv2.imread('C:\\Users\\Lenovo\\Desktop\\five5_28x28.png', 0)
img3 = cv2.imread('C:\\Users\\Lenovo\\Desktop\\eight_28x28.png', 0)
f, (ax0,ax1) = plt.subplots(1, 2)
ax0.imshow(img2,cmap='gray'),ax0.set_title('Five')
ax1.imshow(img3,cmap='gray'),ax1.set_title('Eight')
# Out:
# (<matplotlib.image.AxesImage at 0x244a7a8bf70>, Text(0.5, 1.0, 'Eight'))

# %%
img2 = img2.flatten()
img2 = img2 / 255.
img3 = img3.flatten()
img3= img3 / 255

# %%
np.array([img2]).shape
img2=np.reshape(img2,(28,28,1))
np.array([img3]).shape
img3=np.reshape(img3,(28,28,1))

# %%
out = model.predict(np.array([img2]))
out2 = model.predict(np.array([img3]))
# Out:
# ...
# 1/1 [==============================] - 0s 20ms/step

# %%
out
# Out:
# array([[-4.14798  , -4.117902 , -1.7603836,  3.4669225, -6.3928533,
#          6.0749483, -1.6665999, -2.1783898, -2.854101 , -1.2658029]],
#       dtype=float32)

# %%
out2
# Out:
# array([[-6.304589  ,  0.09652389, -0.01094383,  2.5411363 ,  0.09406053,
#         -0.4386822 , -7.7508907 , -3.879319  , -3.2263958 ,  2.960104  ]],
#       dtype=float32)

# %%
out[0].argmax()
# Out:
# 5

# %%
out2[0].argmax()
# Out:
# 9

# %% [markdown]
# Observation: i tried two models by retraining the data and saving different versions in two different names of models,
# the first model i marked as a comment (models/cnn_mnist_2.h5) it gave false numbers for the two pictures
# the second model (models/cnnMnist_2.h5) after retrain it gave me a better result. The first image it read the 5 correct, the second image it read the 8 as a 9

# %% [markdown]
# retrianing more gave false results the second model was the best one
